# %%
import pandas as pd

# %%
weather = pd.read_csv("https://raw.githubusercontent.com/dataquestio/project-walkthroughs/master/temperature_prediction/weather.csv",index_col="DATE")

# %%
weather.head(5)
# Out:
#                 STATION                              NAME  ACMH   ACSH  AWND  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0   90.0   NaN
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   20.0   NaN
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0  100.0   NaN
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  10.0   20.0   NaN
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   10.0   NaN
#
#             FMTM  PGTM  PRCP  SNOW  SNWD  ...  WT11  WT13  WT14  WT15  WT16  \
# DATE                                      ...
# 1970-01-01   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 1970-01-02   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 1970-01-03   NaN   NaN  0.02   0.0   0.0  ...   NaN   NaN   NaN   NaN   1.0
# 1970-01-04   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 1970-01-05   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
#
#             WT17  WT18  WT21  WT22  WV01
# DATE
# 1970-01-01   NaN   NaN   NaN   NaN   NaN
# 1970-01-02   NaN   NaN   NaN   NaN   NaN
# 1970-01-03   NaN   1.0   NaN   NaN   NaN
# 1970-01-04   NaN   1.0   NaN   NaN   NaN
# 1970-01-05   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 44 columns]

# %%
null_pct = weather.apply(pd.isnull).sum()/weather.shape[0]
null_pct
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.501478
# ACSH       0.501426
# AWND       0.265256
# FMTM       0.475087
# PGTM       0.363872
# PRCP       0.000000
# SNOW       0.000000
# SNWD       0.000104
# TAVG       0.680406
# TMAX       0.000000
# TMIN       0.000000
# TSUN       0.998393
# WDF1       0.501685
# WDF2       0.498678
# WDF5       0.502981
# WDFG       0.734484
# WDFM       0.999948
# WESD       0.685228
# WSF1       0.501530
# WSF2       0.498678
# WSF5       0.503033
# WSFG       0.613055
# WSFM       0.999948
# WT01       0.630217
# WT02       0.935034
# WT03       0.933271
# WT04       0.982579
# WT05       0.981127
# WT06       0.990615
# WT07       0.994400
# WT08       0.796962
# WT09       0.992741
# WT11       0.999274
# WT13       0.886711
# WT14       0.954010
# WT15       0.997822
# WT16       0.658993
# WT17       0.996889
# WT18       0.939493
# WT21       0.999741
# WT22       0.997459
# WV01       0.999948
# dtype: float64

# %%
valid_columns = weather.columns[null_pct < 0.05]
valid_columns
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN'], dtype='object')

# %%
weather = weather[valid_columns].copy()

# %%
weather.columns = weather.columns.str.lower()

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin
# DATE
# 1970-01-01    28    22
# 1970-01-02    31    22
# 1970-01-03    38    25
# 1970-01-04    31    23
# 1970-01-05    35    21
# ...          ...   ...
# 2022-10-17    67    54
# 2022-10-18    58    48
# 2022-10-19    56    43
# 2022-10-20    61    44
# 2022-10-21    64    43
#
# [19287 rows x 7 columns]

# %% [markdown]
# ## FILL THE MISSING VALUES

# %%
weather = weather.ffill()

# %%
weather.apply(pd.isnull).sum()
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.apply(lambda x :(x== 9999).sum())
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.dtypes
# Out:
# station     object
# name        object
# prcp       float64
# snow       float64
# snwd       float64
# tmax         int64
# tmin         int64
# dtype: object

# %%
weather.index
# Out:
# Index(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04', '1970-01-05',
#        '1970-01-06', '1970-01-07', '1970-01-08', '1970-01-09', '1970-01-10',
#        ...
#        '2022-10-12', '2022-10-13', '2022-10-14', '2022-10-15', '2022-10-16',
#        '2022-10-17', '2022-10-18', '2022-10-19', '2022-10-20', '2022-10-21'],
#       dtype='object', name='DATE', length=19287)

# %%
weather.index = pd.to_datetime(weather.index)

# %%
weather.index
# Out:
# DatetimeIndex(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04',
#                '1970-01-05', '1970-01-06', '1970-01-07', '1970-01-08',
#                '1970-01-09', '1970-01-10',
#                ...
#                '2022-10-12', '2022-10-13', '2022-10-14', '2022-10-15',
#                '2022-10-16', '2022-10-17', '2022-10-18', '2022-10-19',
#                '2022-10-20', '2022-10-21'],
#               dtype='datetime64[ns]', name='DATE', length=19287, freq=None)

# %%
weather.index.year.value_counts().sort_index()
# Out:
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    365
# 1986    365
# 1987    365
# 1988    366
# 1989    365
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    294
# Name: DATE, dtype: int64

# %%
weather.columns
# Out:
# Index(['station', 'name', 'prcp', 'snow', 'snwd', 'tmax', 'tmin'], dtype='object')

# %%
weather["snow"].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
weather["target"] = weather.shift(-1)["tmax"]
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# 1970-01-01    28    22    31.0
# 1970-01-02    31    22    38.0
# 1970-01-03    38    25    31.0
# 1970-01-04    31    23    35.0
# 1970-01-05    35    21    36.0
# ...          ...   ...     ...
# 2022-10-17    67    54    58.0
# 2022-10-18    58    48    56.0
# 2022-10-19    56    43    61.0
# 2022-10-20    61    44    64.0
# 2022-10-21    64    43     NaN
#
# [19287 rows x 8 columns]

# %%
weather = weather.ffill()
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# 1970-01-01    28    22    31.0
# 1970-01-02    31    22    38.0
# 1970-01-03    38    25    31.0
# 1970-01-04    31    23    35.0
# 1970-01-05    35    21    36.0
# ...          ...   ...     ...
# 2022-10-17    67    54    58.0
# 2022-10-18    58    48    56.0
# 2022-10-19    56    43    61.0
# 2022-10-20    61    44    64.0
# 2022-10-21    64    43    64.0
#
# [19287 rows x 8 columns]

# %%
from sklearn.linear_model import Ridge
rr = Ridge(alpha=.1)

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])]

# %%
predictors
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin'], dtype='object')

# %%
def backtest(weather,model,predictors, start= 3650, step=90):
    all_predictions = []
    
    for i in range(start, weather.shape[0], step):
        train = weather.iloc[:i,:]
        test = weather.iloc[i:(i+step),:]
    
        model.fit(train[predictors],train["target"])
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]
        combined["diff"] = (combined["prediction"] - combined["actual"]).abs()
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(weather, rr, predictors)

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 5.13932667966084

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1979-12-30    43.0   50.229324   7.229324
# 1979-12-31    42.0   43.673798   1.673798
# 1980-01-01    41.0   41.579150   0.579150
# 1980-01-02    36.0   43.961887   7.961887
# 1980-01-03    30.0   40.204726  10.204726
# ...            ...         ...        ...
# 2022-10-17    58.0   67.543412   9.543412
# 2022-10-18    56.0   60.511771   4.511771
# 2022-10-19    61.0   57.030435   3.969565
# 2022-10-20    64.0   59.784804   4.215196
# 2022-10-21    64.0   60.609742   3.390258
#
# [15637 rows x 3 columns]

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 2007-03-26    78.0   49.744725  28.255275
# 1999-01-02    53.0   25.911898  27.088102
# 1998-03-26    80.0   53.033957  26.966043
# 1985-04-18    84.0   57.071179  26.928821
# 1990-03-12    85.0   58.144310  26.855690
# ...            ...         ...        ...
# 2006-08-20    88.0   88.002937   0.002937
# 2019-03-01    40.0   40.002460   0.002460
# 1992-06-11    76.0   76.001641   0.001641
# 2011-09-16    66.0   66.000831   0.000831
# 2014-03-25    39.0   38.999920   0.000080
#
# [15637 rows x 3 columns]

# %%
pd.Series(rr.coef_, index=predictors)
# Out:
# prcp   -1.236110
# snow   -0.407827
# snwd    0.053422
# tmax    0.447413
# tmin    0.517302
# dtype: float64

# %%
def pct_diff(old, new):
    return (new - old) / old

def compute_rolling(weather, horizon, col):
    label = f"rolling_{horizon}_{col}"
    weather[label] = weather[col].rolling(horizon).mean()
    weather[f"{label}_pct"] = pct_diff(weather[label], weather[col])
    return weather

rolling_horizons = [3, 14]
for horizon in rolling_horizons:
    for col in ["tmax", "tmin", "prcp"]:
        weather = compute_rolling(weather, horizon, col)

# %%
def expand_mean(df):
    return df.expanding(1).mean()

for col in ["tmax", "tmin", "prcp"]:
    weather[f"month_avg_{col}"] = weather[col].groupby(weather.index.month, group_keys=False).apply(expand_mean)
    weather[f"day_avg_{col}"] = weather[col].groupby(weather.index.day_of_year, group_keys=False).apply(expand_mean)

# %%
weather = weather.iloc[14:,:]
weather = weather.fillna(0)

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])]

# %%
predictions = backtest(weather, rr, predictors)
mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 4.789836994367172

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 1990-03-12    85.0   54.400786  30.599214
# 2007-03-26    78.0   49.987728  28.012272
# 1998-03-26    80.0   52.002374  27.997626
# 2003-04-15    86.0   59.398778  26.601222
# 1985-04-18    84.0   58.361709  25.638291
# ...            ...         ...        ...
# 2008-03-10    45.0   44.997105   0.002895
# 1999-09-28    77.0   77.002694   0.002694
# 1994-01-17    37.0   36.999172   0.000828
# 2004-10-29    60.0   59.999430   0.000570
# 2016-02-01    52.0   52.000044   0.000044
#
# [15623 rows x 3 columns]

# %%
weather.loc["1990-03-07": "1990-03-17"]
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1990-03-07  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   2.0
# 1990-03-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   1.0
# 1990-03-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 1990-03-10  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 1990-03-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.05   0.0   0.0
# 1990-03-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-13  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-14  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.26   0.0   0.0
#
#             tmax  tmin  target  rolling_3_tmax  rolling_3_tmax_pct  ...  \
# DATE                                                                ...
# 1990-03-07    32    14    39.0       33.666667           -0.049505  ...
# 1990-03-08    39    20    43.0       35.000000            0.114286  ...
# 1990-03-09    43    29    47.0       38.000000            0.131579  ...
# 1990-03-10    47    39    59.0       43.000000            0.093023  ...
# 1990-03-11    59    41    59.0       49.666667            0.187919  ...
# 1990-03-12    59    43    85.0       55.000000            0.072727  ...
# 1990-03-13    85    41    62.0       67.666667            0.256158  ...
# 1990-03-14    62    46    55.0       68.666667           -0.097087  ...
# 1990-03-15    55    43    62.0       67.333333           -0.183168  ...
# 1990-03-16    62    48    61.0       59.666667            0.039106  ...
# 1990-03-17    61    49    59.0       59.333333            0.028090  ...
#
#             rolling_14_tmin  rolling_14_tmin_pct  rolling_14_prcp  \
# DATE
# 1990-03-07        25.000000            -0.440000         0.047857
# 1990-03-08        24.071429            -0.169139         0.040714
# 1990-03-09        22.785714             0.272727         0.031429
# 1990-03-10        23.428571             0.664634         0.020714
# 1990-03-11        25.500000             0.607843         0.021429
# 1990-03-12        27.928571             0.539642         0.021429
# 1990-03-13        29.500000             0.389831         0.020000
# 1990-03-14        30.857143             0.490741         0.020000
# 1990-03-15        32.214286             0.334812         0.020000
# 1990-03-16        33.428571             0.435897         0.020000
# 1990-03-17        34.357143             0.426195         0.038571
#
#             rolling_14_prcp_pct  month_avg_tmax  day_avg_tmax  month_avg_tmin  \
# DATE
# 1990-03-07            -1.000000       48.590112     45.428571       34.567783
# 1990-03-08            -1.000000       48.574841     46.571429       34.544586
# 1990-03-09            -0.681818       48.565978     45.619048       34.535771
# 1990-03-10            -0.517241       48.563492     43.809524       34.542857
# 1990-03-11             1.333333       48.580032     46.142857       34.553090
# 1990-03-12            -1.000000       48.596519     48.142857       34.566456
# 1990-03-13            -1.000000       48.654028     48.761905       34.576619
# 1990-03-14            -1.000000       48.675079     50.190476       34.594637
# 1990-03-15            -1.000000       48.685039     49.714286       34.607874
# 1990-03-16            -1.000000       48.705975     50.095238       34.628931
# 1990-03-17             5.740741       48.725275     48.095238       34.651491
#
#             day_avg_tmin  month_avg_prcp  day_avg_prcp
# DATE
# 1990-03-07     31.857143        0.119410      0.111429
# 1990-03-08     31.190476        0.119220      0.076667
# 1990-03-09     30.952381        0.119046      0.036190
# 1990-03-10     31.761905        0.118873      0.071905
# 1990-03-11     31.904762        0.118764      0.126667
# 1990-03-12     34.285714        0.118576      0.167619
# 1990-03-13     34.285714        0.118389      0.091429
# 1990-03-14     36.809524        0.118202      0.259524
# 1990-03-15     35.761905        0.118016      0.066667
# 1990-03-16     35.619048        0.117830      0.083810
# 1990-03-17     34.619048        0.118053      0.079048
#
# [11 rows x 26 columns]

# %%
predictions["diff"].round().value_counts().sort_index()
# Out:
# 0.0     1137
# 1.0     2159
# 2.0     1996
# 3.0     1855
# 4.0     1574
# 5.0     1392
# 6.0     1156
# 7.0      996
# 8.0      824
# 9.0      669
# 10.0     515
# 11.0     369
# 12.0     311
# 13.0     186
# 14.0     142
# 15.0      99
# 16.0      79
# 17.0      53
# 18.0      35
# 19.0      20
# 20.0      15
# 21.0      13
# 22.0      11
# 23.0       7
# 24.0       4
# 25.0       1
# 26.0       1
# 27.0       1
# 28.0       2
# 31.0       1
# Name: diff, dtype: int64

# %%
(predictions["diff"].round().value_counts().sort_index() / predictions.shape[0]).plot()
# Out:
# <AxesSubplot:>

# %%
predictions.tail(50)
# Out:
#             actual  prediction       diff
# DATE
# 2022-09-02    79.0   78.121177   0.878823
# 2022-09-03    86.0   79.552364   6.447636
# 2022-09-04    84.0   84.766358   0.766358
# 2022-09-05    75.0   84.623270   9.623270
# 2022-09-06    75.0   77.048699   2.048699
# 2022-09-07    80.0   77.600109   2.399891
# 2022-09-08    79.0   78.925062   0.074938
# 2022-09-09    82.0   77.484778   4.515222
# 2022-09-10    76.0   80.982394   4.982394
# 2022-09-11    79.0   79.310060   0.310060
# 2022-09-12    88.0   79.751792   8.248208
# 2022-09-13    84.0   82.667771   1.332229
# 2022-09-14    76.0   80.261658   4.261658
# 2022-09-15    78.0   76.544876   1.455124
# 2022-09-16    74.0   75.295681   1.295681
# 2022-09-17    84.0   77.977326   6.022674
# 2022-09-18    85.0   81.519534   3.480466
# 2022-09-19    83.0   80.638909   2.361091
# 2022-09-20    78.0   81.064756   3.064756
# 2022-09-21    81.0   76.672899   4.327101
# 2022-09-22    67.0   74.946972   7.946972
# 2022-09-23    72.0   69.971909   2.028091
# 2022-09-24    76.0   71.210444   4.789556
# 2022-09-25    75.0   76.113391   1.113391
# 2022-09-26    72.0   75.622461   3.622461
# 2022-09-27    73.0   74.178977   1.178977
# 2022-09-28    68.0   72.608088   4.608088
# 2022-09-29    64.0   71.875790   7.875790
# 2022-09-30    60.0   69.295617   9.295617
# 2022-10-01    60.0   65.048838   5.048838
# 2022-10-02    52.0   64.452216  12.452216
# 2022-10-03    56.0   60.544525   4.544525
# 2022-10-04    60.0   61.285794   1.285794
# 2022-10-05    76.0   65.211656  10.788344
# 2022-10-06    76.0   68.931295   7.068705
# 2022-10-07    61.0   71.392543  10.392543
# 2022-10-08    64.0   62.327217   1.672783
# 2022-10-09    68.0   63.919537   4.080463
# 2022-10-10    73.0   66.822240   6.177760
# 2022-10-11    68.0   69.152601   1.152601
# 2022-10-12    68.0   67.534477   0.465523
# 2022-10-13    69.0   67.383639   1.616361
# 2022-10-14    68.0   65.910697   2.089303
# 2022-10-15    66.0   64.534211   1.465789
# 2022-10-16    67.0   67.106698   0.106698
# 2022-10-17    58.0   67.010448   9.010448
# 2022-10-18    56.0   62.415946   6.415946
# 2022-10-19    61.0   59.725121   1.274879
# 2022-10-20    64.0   62.351762   1.648238
# 2022-10-21    64.0   63.334734   0.665266

# %%
weather.tail(5)
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target  rolling_3_tmax  rolling_3_tmax_pct  ...  \
# DATE                                                                ...
# 2022-10-17    67    54    58.0       67.000000            0.000000  ...
# 2022-10-18    58    48    56.0       63.666667           -0.089005  ...
# 2022-10-19    56    43    61.0       60.333333           -0.071823  ...
# 2022-10-20    61    44    64.0       58.333333            0.045714  ...
# 2022-10-21    64    43    64.0       60.333333            0.060773  ...
#
#             rolling_14_tmin  rolling_14_tmin_pct  rolling_14_prcp  \
# DATE
# 2022-10-17        50.785714             0.063291         0.233571
# 2022-10-18        50.857143            -0.056180         0.135000
# 2022-10-19        50.000000            -0.140000         0.095714
# 2022-10-20        49.428571            -0.109827         0.095714
# 2022-10-21        48.500000            -0.113402         0.095714
#
#             rolling_14_prcp_pct  month_avg_tmax  day_avg_tmax  month_avg_tmin  \
# DATE
# 2022-10-17            -0.657492       64.843462     63.490566       50.225905
# 2022-10-18            -1.000000       64.839264     63.962264       50.224540
# 2022-10-19            -1.000000       64.833844     62.056604       50.220110
# 2022-10-20            -1.000000       64.831495     62.660377       50.216299
# 2022-10-21            -1.000000       64.830986     63.471698       50.211880
#
#             day_avg_tmin  month_avg_prcp  day_avg_prcp
# DATE
# 2022-10-17     48.962264        0.115316      0.114151
# 2022-10-18     48.943396        0.115245      0.077170
# 2022-10-19     48.132075        0.115175      0.117547
# 2022-10-20     48.471698        0.115104      0.193962
# 2022-10-21     47.867925        0.115034      0.079057
#
# [5 rows x 26 columns]
